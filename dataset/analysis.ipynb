# %%
import pandas as pd
import numpy as np

# %%
pd.read_csv('can_receive_logs\model3_C.csv')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\m'
# <>:1: SyntaxWarning: invalid escape sequence '\m'
# C:\Users\fordr\AppData\Local\Temp\ipykernel_35780\344150231.py:1: SyntaxWarning: invalid escape sequence '\m'
#   pd.read_csv('can_receive_logs\model3_C.csv')
#         NUMBER  TIME_OFFSET TYPE    ID  DLC DATA_1 DATA_2 DATA_3 DATA_4  \
# 0            1     4.913391   Rx  0000    0    NaN    NaN    NaN    NaN
# 1            2     4.914358   Rx  0370    8     12     01     08     1D
# 2            3     4.914639   Rx  0187    8     21     65     EA     00
# 3            4     4.914868   Rx  02D5    8     94     15     14     91
# 4            5     4.915157   Rx  0186    8     8E     05     00     02
# ...        ...          ...  ...   ...  ...    ...    ...    ...    ...
# 599996  599997   196.512284   Rx  02D5    8     C3     4F     14     86
# 599997  599998   196.512556   Rx  0186    8     3D     0F     00     02
# 599998  599999   196.512775   Rx  0385    8     70     6F     F7     80
# 599999  600000   196.512920   Rx  038B    4     61     4D     20     00
# 600000  600001   196.514179   Rx  018A    8     BF     3A     8D     D3
#
#        DATA_5 DATA_6 DATA_7 DATA_8  DELTA_TIME
# 0         NaN    NaN    NaN    NaN    4.913391
# 1          1F     BD     20     A7    0.000967
# 2          60     EA     00     00    0.000281
# 3          03     00     00     00    0.000229
# 4          00     00     00     00    0.000289
# ...       ...    ...    ...    ...         ...
# 599996     03     00     00     00    0.000247
# 599997     00     97     0E     00    0.000272
# 599998     00     00     D0     AE    0.000219
# 599999    NaN    NaN    NaN    NaN    0.000145
# 600000     35     8D     D3     05    0.001259
#
# [600001 rows x 14 columns]

# %%
# Read the CSV file into a DataFrame
df = pd.read_csv('can_receive_logs\model3_C.csv')

# Count the frequency of each ID
id_counts = df['ID'].value_counts()
id_counts.to_csv('id_counts.csv', header=True)
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\m'
# <>:2: SyntaxWarning: invalid escape sequence '\m'
# C:\Users\fordr\AppData\Local\Temp\ipykernel_35780\939983988.py:2: SyntaxWarning: invalid escape sequence '\m'
#   df = pd.read_csv('can_receive_logs\model3_C.csv')

# %%
id_counts.plot(kind='bar', figsize=(12, 6), title='Top 20 Most Frequent IDs from Tesla Model 3 C-CAN')
# Out:
# <Axes: title={'center': 'Top 20 Most Frequent IDs from Tesla Model 3 C-CAN'}, xlabel='ID'>
